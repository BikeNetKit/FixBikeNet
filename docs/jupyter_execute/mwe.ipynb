# %% [markdown]
# # Minimum working example
# This notebook runs a minimum working example with fixbikenet.

# %% [markdown]
# ## Import fixbikenet

# %% [markdown]
# The standard way of importing fixbikenet:

# %%
import fixbikenet as fbn

# %% [markdown]
# ## Run fixbikenet on example city

# %%
gaps = fbn.fixbikenet("Frederiksberg municipality")
# Out:
# ===============================================
# RUNNING FIXBIKENET FOR CITY: Frederiksberg municipality
# -----------------------------------------------╮
# Downloading OSM data    :   0%|                | 0/1 [00:00<?, ?network/s]
# Processing network      :   0%|                | 0/2 [00:00<?, ?step/s]
# Dropping parallel edges :   0%|                | 0/238 [00:00<?, ?edge/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gaps = fbn.fixbikenet("Frederiksberg municipality")
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/fixbikenet/fixbikenet.py:149, in fixbikenet(city_query, radius, mingap, maxgap, numgaps, export_data, city_id, export_plot, import_files)
#     147 # creating new gdfs for nodes and edges of G
#     148 nodes_gdf = graph_nodes_to_gdf(G)
# --> 149 edges_gdf = graph_edges_to_gdf(G)
#     150 _resolve_crs_calculations(nodes_gdf)
#     151 nodes_gdf = nodes_gdf.to_crs(constants._CRS_CALCULATIONS)
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/fixbikenet/functions.py:613, in graph_edges_to_gdf(G)
#     610         geom = data["geometry"]
#     611     else:
#     612         # otherwise build a straight line from node coordinates
# --> 613         geom = LineString([
#     614             (G.nodes[u]["x"], G.nodes[u]["y"]),
#     615             (G.nodes[v]["x"], G.nodes[v]["y"])
#     616         ])
#     617     rows.append({
#     618         "u": u,
#     619         "v": v,
#     620         **data,
#     621         "geometry": geom
#     622     })
#     623 edges_gdf = gpd.GeoDataFrame(
#     624     rows,
#     625     geometry="geometry",
#     626     crs=G.graph.get("crs")
#     627 ).set_index(["u", "v"])
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/shapely/geometry/linestring.py:76, in LineString.__new__(self, coordinates)
#      71 if len(coordinates) == 0:
#      72     # empty geometry
#      73     # TODO better constructor + should shapely.linestrings handle this?
#      74     return shapely.from_wkt("LINESTRING EMPTY")
# ---> 76 geom = shapely.linestrings(coordinates)
#      77 if not isinstance(geom, LineString):
#      78     raise ValueError("Invalid values passed to LineString constructor")
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/shapely/decorators.py:173, in deprecate_positional.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @wraps(func)
#     172 def wrapper(*args, **kwargs):
# --> 173     result = func(*args, **kwargs)
#     175     n = len(args)
#     176     if n > warn_from:
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/shapely/decorators.py:76, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      73 @wraps(func)
#      74 def wrapped(*args, **kwargs):
#      75     array_args = [
# ---> 76         arg for arg in args if isinstance(arg, np.ndarray) and arg.dtype == object
#      77     ] + [
#      78         arg
#      79         for name, arg in kwargs.items()
#      80         if name not in {"where", "out"}
#      81         and isinstance(arg, np.ndarray)
#      82         and arg.dtype == object
#      83     ]
#      84     old_flags = [arr.flags.writeable for arr in array_args]
#      85     try:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Explore results

# %% [markdown]
# See the contents of the resulting geodataframe:

# %%
gaps.head()
# Out:
#                                                 path        benefit name  \
# 0         [576734, 982458401, 1602521961, 929287662]  114509.773337  n/a
# 1                               [8088739, 369902569]   65684.000000  n/a
# 2                               [8088739, 271447788]   51073.000000  n/a
# 3   [1629778132, 1629778158, 1631231681, 5771168117]   42247.092427  n/a
# 4  [781056, 1622070812, 1622070808, 1622070849, 5...   37662.754856  n/a
#
#                                            edge_list      source       target  \
# 0  [(576734, 982458401), (982458401, 1602521961),...      576734    929287662
# 1                             [(8088739, 369902569)]     8088739    369902569
# 2                             [(8088739, 271447788)]     8088739    271447788
# 3  [(1629778132, 1629778158), (1629778158, 163123...  1629778132   5771168117
# 4  [(781056, 1622070812), (1622070808, 1622070812...      781056  13824074631
#
#    ordering      length                                           geometry
# 0         0  189.228303  LINESTRING (12.5214 55.67937, 12.52136 55.6792...
# 1         1   22.498959  LINESTRING (12.51731 55.67908, 12.51732 55.679...
# 2         2   15.787892  LINESTRING (12.51731 55.67908, 12.5173 55.679,...
# 3         3  153.661596  LINESTRING (12.53946 55.67056, 12.53931 55.670...
# 4         4  210.350752  LINESTRING (12.54403 55.68123, 12.54361 55.681...

# %% [markdown]
# Explore the results interactively:

# %%
gaps.explore(
    tiles="CartoDB Positron", # background map
    style_kwds={"weight": 3, "color": "#096a51"}, # thick green lines
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a460cd249366d3974f12672c27b5f497 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a460cd249366d3974f12672c27b5f497&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a460cd249366d3974f12672c27b5f497 = L.map(
#                 &quot;map_a460cd249366d3974f12672c27b5f497&quot;,
#                 {
#                     center: [55.679691399999996, 12.5285409],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a460cd249366d3974f12672c27b5f497);
#
#
#
#
#
#             var tile_layer_fb49c149b02512d5eb196dbc412ff1aa = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb49c149b02512d5eb196dbc412ff1aa.addTo(map_a460cd249366d3974f12672c27b5f497);
#
#
#             map_a460cd249366d3974f12672c27b5f497.fitBounds(
#                 [[55.668475, 12.5021593], [55.6909078, 12.5549225]],
#                 {}
#             );
#
#
#         function geo_json_4018dca7dde886e0792a6d3a68bd6331_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#096a51&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 3};
#             }
#         }
#         function geo_json_4018dca7dde886e0792a6d3a68bd6331_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4018dca7dde886e0792a6d3a68bd6331_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_4018dca7dde886e0792a6d3a68bd6331_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4018dca7dde886e0792a6d3a68bd6331_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_4018dca7dde886e0792a6d3a68bd6331.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4018dca7dde886e0792a6d3a68bd6331_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4018dca7dde886e0792a6d3a68bd6331 = L.geoJson(null, {
#                 onEachFeature: geo_json_4018dca7dde886e0792a6d3a68bd6331_onEachFeature,
#
#                 style: geo_json_4018dca7dde886e0792a6d3a68bd6331_styler,
#                 pointToLayer: geo_json_4018dca7dde886e0792a6d3a68bd6331_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_4018dca7dde886e0792a6d3a68bd6331_add (data) {
#             geo_json_4018dca7dde886e0792a6d3a68bd6331
#                 .addData(data);
#         }
#             geo_json_4018dca7dde886e0792a6d3a68bd6331_add({&quot;bbox&quot;: [12.5021593, 55.668475, 12.5549225, 55.6909078], &quot;features&quot;: [{&quot;bbox&quot;: [12.5207092, 55.6777124, 12.5213985, 55.679366599999994], &quot;geometry&quot;: {&quot;coordinates&quot;: [[12.5213985, 55.679366599999994], [12.521357500000002, 55.67925279999999], [12.5213494, 55.67923189999999], [12

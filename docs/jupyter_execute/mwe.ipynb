# %% [markdown]
# ## Minimum working example
# This notebook runs a minimum working example with fixbikenet.

# %% [markdown]
# ### Import fixbikenet

# %% [markdown]
# The standard way of importing fixbikenet:

# %%
import fixbikenet as fbn

# %% [markdown]
# ### Run fixbikenet with example city Frederiksberg

# %%
gaps = fbn.fixbikenet("Frederiksberg municipality")
# Out:
# Downloading OSM data..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gaps = fbn.fixbikenet("Frederiksberg municipality")
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/fixbikenet/fixbikenet.py:68, in fixbikenet(city_name, proj_crs, radius, maxgap, penalty, export_data, export_file_format, export_plot)
#      65 ox.settings.useful_tags_way = ["highway", "cycleway", "cycleway:right", "cycleway:left", "cycleway:both", "cyclestreet"]
#      67 # fetch street network data from osmnx
# ---> 68 g = ox.graph_from_place(
#      69     city_name, network_type='all', simplify=False
#      70 )
#      71 g = ox.simplify_graph(
#      72     g,
#      73     edge_attrs_differ=['cycleway', 'highway', 'cycleway:right', 'cycleway:left', 'cycleway:both']
#      74 )
#      76 # export osmnx data to gdfs
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/osmnx/graph.py:396, in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, which_result, custom_filter)
#     393 utils.log(msg, level=lg.INFO)
#     395 # create graph using this polygon(s) geometry
# --> 396 G = graph_from_polygon(
#     397     polygon,
#     398     network_type=network_type,
#     399     simplify=simplify,
#     400     retain_all=retain_all,
#     401     truncate_by_edge=truncate_by_edge,
#     402     custom_filter=custom_filter,
#     403 )
#     405 msg = f"graph_from_place returned graph with {len(G):,} nodes and {len(G.edges):,} edges"
#     406 utils.log(msg, level=lg.INFO)
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/osmnx/graph.py:496, in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, custom_filter)
#     494 # create buffered graph from the downloaded data
#     495 bidirectional = network_type in settings.bidirectional_network_types
# --> 496 G_buff = _create_graph(response_jsons, bidirectional)
#     498 # truncate buffered graph to the buffered polygon and retain_all for
#     499 # now. needed because overpass returns entire ways that also include
#     500 # nodes outside the poly if the way (that is, a way with a single OSM
#     501 # ID) has a node inside the poly at some point.
#     502 G_buff = truncate.truncate_graph_polygon(G_buff, poly_buff, truncate_by_edge=truncate_by_edge)
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/osmnx/graph.py:625, in _create_graph(response_jsons, bidirectional)
#     621 # consume response_jsons generator to download data from server. if
#     622 # cache_only_mode, just consume response_jsons then continue next loop.
#     623 # otherwise, extract nodes and paths from the downloaded OSM data.
#     624 response_count = 0
# --> 625 for response_json in response_jsons:
#     626     response_count += 1
#     627     if not settings.cache_only_mode:
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/osmnx/_overpass.py:402, in _download_overpass_network(polygon, network_type, custom_filter)
#     400 for way_filter in way_filters:
#     401     query_str = f"{overpass_settings};(way{way_filter}(poly:{polygon_coord_str!r});>;);out;"
# --> 402     yield _overpass_request(OrderedDict(data=query_str))
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/osmnx/_overpass.py:469, in _overpass_request(data)
#     467 msg = f"Post {prepared_url} with timeout={settings.requests_timeout}"
#     468 utils.log(msg, level=lg.INFO)
# --> 469 response = requests.post(
#     470     url,
#     471     data=data,
#     472     timeout=settings.requests_timeout,
#     473     headers=_http._get_http_headers(),
#     474     **settings.requests_kwargs,
#     475 )
#     477 # handle 429 and 504 errors by pausing then recursively re-trying request
#     478 if response.status_code in {429, 504}:  # pragma: no cover
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/requests/api.py:134, in post(url, data, json, **kwargs)
#     117 def post(
#     118     url: _t.UriType,
#     119     data: _t.DataType = None,
#     120     json: _t.JsonType = None,
#     121     **kwargs: Unpack[_t.PostKwargs],
#     122 ) -> Response:
#     123     r"""Sends a POST request.
#     124
#     125     :param url: URL for the new :class:`Request` object.
#    (...)    131     :rtype: requests.Response
#     132     """
# --> 134     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/requests/api.py:71, in request(method, url, **kwargs)
#      67 # By using the 'with' statement we are sure the session is closed, thus we
#      68 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      69 # cases, and look like a memory leak in others.
#      70 with sessions.Session() as session:
# ---> 71     return session.request(method=method, url=url, **kwargs)
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/requests/sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/requests/sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/requests/adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     693     resolved_timeout = TimeoutSauce(connect=timeout, read=timeout)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#     711     raise ConnectionError(err, request=request)
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/urllib3/connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785 response_conn = conn if not release_conn else None
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#     804 clean_exit = True
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/http/client.py:1478, in HTTPConnection.getresponse(self)
#    1476 try:
#    1477     try:
# -> 1478         response.begin()
#    1479     except ConnectionError:
#    1480         self.close()
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/http/client.py:343, in HTTPResponse.begin(self)
#     341 # read until we get a non-100 response
#     342 for _ in range(_MAXINTERIMRESPONSES):
# --> 343     version, status, reason = self._read_status()
#     344     if status != CONTINUE:
#     345         break
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/http/client.py:304, in HTTPResponse._read_status(self)
#     303 def _read_status(self):
# --> 304     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     305     if len(line) > _MAXLINE:
#     306         raise LineTooLong("status line")
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/socket.py:729, in SocketIO.readinto(self, b)
#     727     raise OSError("cannot read from timed out object")
#     728 try:
# --> 729     return self._sock.recv_into(b)
#     730 except timeout:
#     731     self._timeout_occurred = True
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/Github/BikeNetKit/FixBikeNet/.pixi/envs/default/lib/python3.14/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# data is saved in `.examples/` as `gaps.gpk`
